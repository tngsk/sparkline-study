# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0,1000)

# %%
y = np.random.randn(1000)

# %%
plt.plot(x,y)

# %%
df = pd.DataFrame(index=[], columns=[])

# %%
y_ser = pd.Series(y, name='y')
y_ser
# Out:
# 0      0.061199
# 1     -0.659804
# 2      0.340600
# 3     -1.094073
# 4      0.751611
#          ...
# 995    0.622426
# 996   -0.755656
# 997    1.806369
# 998    0.670597
# 999    1.932249
# Name: y, Length: 1000, dtype: float64

# %%
df = pd.concat([df,y_ser])

# %%
df.to_csv('./data.csv', header=['Data'])
